# %% [markdown]
# Plotting
# 1.Line Graphs
# 2.Bar Graphs
# 3. Heat Maps

# %%
import pandas as pd
import numpy as np
import seaborn as sns #pip install sns
from matplotlib.pyplot import title

df = pd.DataFrame(index=['20210101','20210102','20210103','20210104'])
df['X']=[1,1.1,1.3,1.25]
df['Y']=[0.8,0.9,0.75,0.6]
df['Z']=[0.99,0.95,0.75,0.6]
df
# Out:
#              X     Y     Z
# 20210101  1.00  0.80  0.99
# 20210102  1.10  0.90  0.95
# 20210103  1.30  0.75  0.75
# 20210104  1.25  0.60  0.60

# %%
df['X'].plot(title='X Line Plot')
# Out:
# <Axes: title={'center': 'X Line Plot'}>

# %%
df.plot(title='DataFrame Line Plot')
# Out:
# <Axes: title={'center': 'DataFrame Line Plot'}>

# %%
df.plot(title='DataFrame Line Plot',style='-*')
# Out:
# <Axes: title={'center': 'DataFrame Line Plot'}>

# %%
df['X'].plot(kind='bar',title='X bar plot')
# Out:
# <Axes: title={'center': 'X bar plot'}>

# %%
df.plot(kind='bar', title='DataFrame Bar plot')
# Out:
# <Axes: title={'center': 'DataFrame Bar plot'}>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >
